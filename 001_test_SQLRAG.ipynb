# %% [markdown]
# # テスト用ノートブック

# %% [markdown]
# ### 参考資料
# https://qiita.com/tatsuki-tsuchiyama/items/4c996ce740cc0c607d35

# %%
import configparser
from langchain.agents import create_sql_agent
from langchain.agents.agent_toolkits import SQLDatabaseToolkit
from langchain.agents.agent_types import AgentType
from langchain.chat_models import ChatOpenAI
from langchain.sql_database import SQLDatabase

# %%
# 設定ファイルの読み込み
config = configparser.ConfigParser() #Configのハンドル設定
config.read("./private/config.ini")

#OpenAI部分の設定参照
openai_config = config["OPENAI"] 
input_openai_api_key = openai_config["OPENAI_API_KEY"]

# %%
#データベースとモデルの設定
db = SQLDatabase.from_uri("sqlite:///./db/chinook.db")

# %%
llm = ChatOpenAI(
    openai_api_key=input_openai_api_key,
    temperature=0,
    model_name="gpt-3.5-turbo",
    streaming=True
)

# %%
toolkit = SQLDatabaseToolkit(db=db, llm=llm)

# %%
agent_executor = create_sql_agent(
    llm=llm,
    toolkit=toolkit,
    verbose=True,
    agent_type=AgentType.OPENAI_FUNCTIONS,
)

# %%
agent_executor.run("いくつのデータが存在しますか？")
# Out:
# > Entering new  chain...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 agent_executor.run("いくつのデータが存在しますか？")
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chains\base.py:273, in Chain.run(self, callbacks, tags, *args, **kwargs)
#     271     if len(args) != 1:
#     272         raise ValueError("`run` supports only one positional argument.")
# --> 273     return self(args[0], callbacks=callbacks, tags=tags)[_output_key]
#     275 if kwargs and not args:
#     276     return self(kwargs, callbacks=callbacks, tags=tags)[_output_key]
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chains\base.py:149, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     147 except (KeyboardInterrupt, Exception) as e:
#     148     run_manager.on_chain_error(e)
# --> 149     raise e
#     150 run_manager.on_chain_end(outputs)
#     151 final_outputs: Dict[str, Any] = self.prep_outputs(
#     152     inputs, outputs, return_only_outputs
#     153 )
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chains\base.py:143, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, include_run_info)
#     137 run_manager = callback_manager.on_chain_start(
#     138     dumpd(self),
#     139     inputs,
#     140 )
#     141 try:
#     142     outputs = (
# --> 143         self._call(inputs, run_manager=run_manager)
#     144         if new_arg_supported
#     145         else self._call(inputs)
#     146     )
#     147 except (KeyboardInterrupt, Exception) as e:
#     148     run_manager.on_chain_error(e)
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\agents\agent.py:957, in AgentExecutor._call(self, inputs, run_manager)
#     955 # We now enter the agent loop (until it returns something).
#     956 while self._should_continue(iterations, time_elapsed):
# --> 957     next_step_output = self._take_next_step(
#     958         name_to_tool_map,
#     959         color_mapping,
#     960         inputs,
#     961         intermediate_steps,
#     962         run_manager=run_manager,
#     963     )
#     964     if isinstance(next_step_output, AgentFinish):
#     965         return self._return(
#     966             next_step_output, intermediate_steps, run_manager=run_manager
#     967         )
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\agents\agent.py:762, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#     756 """Take a single step in the thought-action-observation loop.
#     757
#     758 Override this to take control of how the agent makes and acts on choices.
#     759 """
#     760 try:
#     761     # Call the LLM to see what to do.
# --> 762     output = self.agent.plan(
#     763         intermediate_steps,
#     764         callbacks=run_manager.get_child() if run_manager else None,
#     765         **inputs,
#     766     )
#     767 except OutputParserException as e:
#     768     if isinstance(self.handle_parsing_errors, bool):
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\agents\openai_functions_agent\base.py:209, in OpenAIFunctionsAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     207 prompt = self.prompt.format_prompt(**full_inputs)
#     208 messages = prompt.to_messages()
# --> 209 predicted_message = self.llm.predict_messages(
#     210     messages, functions=self.functions, callbacks=callbacks
#     211 )
#     212 agent_decision = _parse_ai_message(predicted_message)
#     213 return agent_decision
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chat_models\base.py:258, in BaseChatModel.predict_messages(self, messages, stop, **kwargs)
#     256 else:
#     257     _stop = list(stop)
# --> 258 return self(messages, stop=_stop, **kwargs)
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chat_models\base.py:208, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     201 def __call__(
#     202     self,
#     203     messages: List[BaseMessage],
#    (...)
#     206     **kwargs: Any,
#     207 ) -> BaseMessage:
# --> 208     generation = self.generate(
#     209         [messages], stop=stop, callbacks=callbacks, **kwargs
#     210     ).generations[0][0]
#     211     if isinstance(generation, ChatGeneration):
#     212         return generation.message
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chat_models\base.py:102, in BaseChatModel.generate(self, messages, stop, callbacks, tags, **kwargs)
#     100 except (KeyboardInterrupt, Exception) as e:
#     101     run_manager.on_llm_error(e)
# --> 102     raise e
#     103 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#     104 generations = [res.generations for res in results]
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chat_models\base.py:94, in BaseChatModel.generate(self, messages, stop, callbacks, tags, **kwargs)
#      90 new_arg_supported = inspect.signature(self._generate).parameters.get(
#      91     "run_manager"
#      92 )
#      93 try:
# ---> 94     results = [
#      95         self._generate(m, stop=stop, run_manager=run_manager, **kwargs)
#      96         if new_arg_supported
#      97         else self._generate(m, stop=stop)
#      98         for m in messages
#      99     ]
#     100 except (KeyboardInterrupt, Exception) as e:
#     101     run_manager.on_llm_error(e)
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chat_models\base.py:95, in <listcomp>(.0)
#      90 new_arg_supported = inspect.signature(self._generate).parameters.get(
#      91     "run_manager"
#      92 )
#      93 try:
#      94     results = [
# ---> 95         self._generate(m, stop=stop, run_manager=run_manager, **kwargs)
#      96         if new_arg_supported
#      97         else self._generate(m, stop=stop)
#      98         for m in messages
#      99     ]
#     100 except (KeyboardInterrupt, Exception) as e:
#     101     run_manager.on_llm_error(e)
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chat_models\openai.py:331, in ChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     329 params["stream"] = True
#     330 function_call: Optional[dict] = None
# --> 331 for stream_resp in self.completion_with_retry(
#     332     messages=message_dicts, **params
#     333 ):
#     334     role = stream_resp["choices"][0]["delta"].get("role", role)
#     335     token = stream_resp["choices"][0]["delta"].get("content") or ""
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chat_models\openai.py:295, in ChatOpenAI.completion_with_retry(self, **kwargs)
#     293 def completion_with_retry(self, **kwargs: Any) -> Any:
#     294     """Use tenacity to retry the completion call."""
# --> 295     retry_decorator = self._create_retry_decorator()
#     297     @retry_decorator
#     298     def _completion_with_retry(**kwargs: Any) -> Any:
#     299         return self.client.create(**kwargs)
#
# File c:\01_program\01_github\101_003_Zenn_Webapp_Langchain-streamlit\venv\llm_app\Lib\site-packages\langchain\chat_models\openai.py:284, in ChatOpenAI._create_retry_decorator(self)
#     276 max_seconds = 60
#     277 # Wait 2^x * 1 second between each retry starting with
#     278 # 4 seconds, then up to 10 seconds, then 10 seconds afterwards
#     279 return retry(
#     280     reraise=True,
#     281     stop=stop_after_attempt(self.max_retries),
#     282     wait=wait_exponential(multiplier=1, min=min_seconds, max=max_seconds),
#     283     retry=(
# --> 284         retry_if_exception_type(openai.error.Timeout)
#     285         | retry_if_exception_type(openai.error.APIError)
#     286         | retry_if_exception_type(openai.error.APIConnectionError)
#     287         | retry_if_exception_type(openai.error.RateLimitError)
#     288         | retry_if_exception_type(openai.error.ServiceUnavailableError)
#     289     ),
#     290     before_sleep=before_sleep_log(logger, logging.WARNING),
#     291 )
#
# AttributeError: module 'openai' has no attribute 'error'

# %%
agent_executor.run("データ項目を教えて")
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_list_tables` with `{}`
#
#
# albums, artists, customers, employees, genres, invoice_items, invoices, media_types, playlist_track, playlists, tracks
# Invoking: `sql_db_schema` with `{'table_names': 'albums, artists, customers, employees, genres, invoice_items, invoices, media_types, playlist_track, playlists, tracks'}`
#
#
#
# CREATE TABLE albums (
# 	"AlbumId" INTEGER NOT NULL,
# 	"Title" NVARCHAR(160) NOT NULL,
# 	"ArtistId" INTEGER NOT NULL,
# 	PRIMARY KEY ("AlbumId"),
# 	FOREIGN KEY("ArtistId") REFERENCES artists ("ArtistId")
# )
#
# /*
# 3 rows from albums table:
# AlbumId	Title	ArtistId
# 1	For Those About To Rock We Salute You	1
# 2	Balls to the Wall	2
# 3	Restless and Wild	2
# */
#
#
# CREATE TABLE artists (
# 	"ArtistId" INTEGER NOT NULL,
# 	"Name" NVARCHAR(120),
# 	PRIMARY KEY ("ArtistId")
# )
#
# /*
# 3 rows from artists table:
# ArtistId	Name
# 1	AC/DC
# 2	Accept
# 3	Aerosmith
# */
#
#
# CREATE TABLE customers (
# 	"CustomerId" INTEGER NOT NULL,
# 	"FirstName" NVARCHAR(40) NOT NULL,
# 	"LastName" NVARCHAR(20) NOT NULL,
# 	"Company" NVARCHAR(80),
# 	"Address" NVARCHAR(70),
# 	"City" NVARCHAR(40),
# 	"State" NVARCHAR(40),
# 	"Country" NVARCHAR(40),
# 	"PostalCode" NVARCHAR(10),
# 	"Phone" NVARCHAR(24),
# 	"Fax" NVARCHAR(24),
# 	"Email" NVARCHAR(60) NOT NULL,
# 	"SupportRepId" INTEGER,
# 	PRIMARY KEY ("CustomerId"),
# 	FOREIGN KEY("SupportRepId") REFERENCES employees ("EmployeeId")
# )
#
# /*
# 3 rows from customers table:
# CustomerId	FirstName	LastName	Company	Address	City	State	Country	PostalCode	Phone	Fax	Email	SupportRepId
# 1	Luís	Gonçalves	Embraer - Empresa Brasileira de Aeronáutica S.A.	Av. Brigadeiro Faria Lima, 2170	São José dos Campos	SP	Brazil	12227-000	+55 (12) 3923-5555	+55 (12) 3923-5566	luisg@embraer.com.br	3
# 2	Leonie	Köhler	None	Theodor-Heuss-Straße 34	Stuttgart	None	Germany	70174	+49 0711 2842222	None	leonekohler@surfeu.de	5
# 3	François	Tremblay	None	1498 rue Bélanger	Montréal	QC	Canada	H2G 1A7	+1 (514) 721-4711	None	ftremblay@gmail.com	3
# */
#
#
# CREATE TABLE employees (
# 	"EmployeeId" INTEGER NOT NULL,
# 	"LastName" NVARCHAR(20) NOT NULL,
# 	"FirstName" NVARCHAR(20) NOT NULL,
# 	"Title" NVARCHAR(30),
# 	"ReportsTo" INTEGER,
# 	"BirthDate" DATETIME,
# 	"HireDate" DATETIME,
# 	"Address" NVARCHAR(70),
# 	"City" NVARCHAR(40),
# 	"State" NVARCHAR(40),
# 	"Country" NVARCHAR(40),
# 	"PostalCode" NVARCHAR(10),
# 	"Phone" NVARCHAR(24),
# 	"Fax" NVARCHAR(24),
# 	"Email" NVARCHAR(60),
# 	PRIMARY KEY ("EmployeeId"),
# 	FOREIGN KEY("ReportsTo") REFERENCES employees ("EmployeeId")
# )
#
# /*
# 3 rows from employees table:
# EmployeeId	LastName	FirstName	Title	ReportsTo	BirthDate	HireDate	Address	City	State	Country	PostalCode	Phone	Fax	Email
# 1	Adams	Andrew	General Manager	None	1962-02-18 00:00:00	2002-08-14 00:00:00	11120 Jasper Ave NW	Edmonton	AB	Canada	T5K 2N1	+1 (780) 428-9482	+1 (780) 428-3457	andrew@chinookcorp.com
# 2	Edwards	Nancy	Sales Manager	1	1958-12-08 00:00:00	2002-05-01 00:00:00	825 8 Ave SW	Calgary	AB	Canada	T2P 2T3	+1 (403) 262-3443	+1 (403) 262-3322	nancy@chinookcorp.com
# 3	Peacock	Jane	Sales Support Agent	2	1973-08-29 00:00:00	2002-04-01 00:00:00	1111 6 Ave SW	Calgary	AB	Canada	T2P 5M5	+1 (403) 262-3443	+1 (403) 262-6712	jane@chinookcorp.com
# */
#
#
# CREATE TABLE genres (
# 	"GenreId" INTEGER NOT NULL,
# 	"Name" NVARCHAR(120),
# 	PRIMARY KEY ("GenreId")
# )
#
# /*
# 3 rows from genres table:
# GenreId	Name
# 1	Rock
# 2	Jazz
# 3	Metal
# */
#
#
# CREATE TABLE invoice_items (
# 	"InvoiceLineId" INTEGER NOT NULL,
# 	"InvoiceId" INTEGER NOT NULL,
# 	"TrackId" INTEGER NOT NULL,
# 	"UnitPrice" NUMERIC(10, 2) NOT NULL,
# 	"Quantity" INTEGER NOT NULL,
# 	PRIMARY KEY ("InvoiceLineId"),
# 	FOREIGN KEY("TrackId") REFERENCES tracks ("TrackId"),
# 	FOREIGN KEY("InvoiceId") REFERENCES invoices ("InvoiceId")
# )
#
# /*
# 3 rows from invoice_items table:
# InvoiceLineId	InvoiceId	TrackId	UnitPrice	Quantity
# 1	1	2	0.99	1
# 2	1	4	0.99	1
# 3	2	6	0.99	1
# */
#
#
# CREATE TABLE invoices (
# 	"InvoiceId" INTEGER NOT NULL,
# 	"CustomerId" INTEGER NOT NULL,
# 	"InvoiceDate" DATETIME NOT NULL,
# 	"BillingAddress" NVARCHAR(70),
# 	"BillingCity" NVARCHAR(40),
# 	"BillingState" NVARCHAR(40),
# 	"BillingCountry" NVARCHAR(40),
# 	"BillingPostalCode" NVARCHAR(10),
# 	"Total" NUMERIC(10, 2) NOT NULL,
# 	PRIMARY KEY ("InvoiceId"),
# 	FOREIGN KEY("CustomerId") REFERENCES customers ("CustomerId")
# )
#
# /*
# 3 rows from invoices table:
# InvoiceId	CustomerId	InvoiceDate	BillingAddress	BillingCity	BillingState	BillingCountry	BillingPostalCode	Total
# 1	2	2009-01-01 00:00:00	Theodor-Heuss-Straße 34	Stuttgart	None	Germany	70174	1.98
# 2	4	2009-01-02 00:00:00	Ullevålsveien 14	Oslo	None	Norway	0171	3.96
# 3	8	2009-01-03 00:00:00	Grétrystraat 63	Brussels	None	Belgium	1000	5.94
# */
#
#
# CREATE TABLE media_types (
# 	"MediaTypeId" INTEGER NOT NULL,
# 	"Name" NVARCHAR(120),
# 	PRIMARY KEY ("MediaTypeId")
# )
#
# /*
# 3 rows from media_types table:
# MediaTypeId	Name
# 1	MPEG audio file
# 2	Protected AAC audio file
# 3	Protected MPEG-4 video file
# */
#
#
# CREATE TABLE playlist_track (
# 	"PlaylistId" INTEGER NOT NULL,
# 	"TrackId" INTEGER NOT NULL,
# 	PRIMARY KEY ("PlaylistId", "TrackId"),
# 	FOREIGN KEY("TrackId") REFERENCES tracks ("TrackId"),
# 	FOREIGN KEY("PlaylistId") REFERENCES playlists ("PlaylistId")
# )
#
# /*
# 3 rows from playlist_track table:
# PlaylistId	TrackId
# 1	3402
# 1	3389
# 1	3390
# */
#
#
# CREATE TABLE playlists (
# 	"PlaylistId" INTEGER NOT NULL,
# 	"Name" NVARCHAR(120),
# 	PRIMARY KEY ("PlaylistId")
# )
#
# /*
# 3 rows from playlists table:
# PlaylistId	Name
# 1	Music
# 2	Movies
# 3	TV Shows
# */
#
#
# CREATE TABLE tracks (
# 	"TrackId" INTEGER NOT NULL,
# 	"Name" NVARCHAR(200) NOT NULL,
# 	"AlbumId" INTEGER,
# 	"MediaTypeId" INTEGER NOT NULL,
# 	"GenreId" INTEGER,
# 	"Composer" NVARCHAR(220),
# 	"Milliseconds" INTEGER NOT NULL,
# 	"Bytes" INTEGER,
# 	"UnitPrice" NUMERIC(10, 2) NOT NULL,
# 	PRIMARY KEY ("TrackId"),
# 	FOREIGN KEY("MediaTypeId") REFERENCES media_types ("MediaTypeId"),
# 	FOREIGN KEY("GenreId") REFERENCES genres ("GenreId"),
# 	FOREIGN KEY("AlbumId") REFERENCES albums ("AlbumId")
# )
#
# /*
# 3 rows from tracks table:
# TrackId	Name	AlbumId	MediaTypeId	GenreId	Composer	Milliseconds	Bytes	UnitPrice
# 1	For Those About To Rock (We Salute You)	1	1	1	Angus Young, Malcolm Young, Brian Johnson	343719	11170334	0.99
# 2	Balls to the Wall	2	2	1	None	342562	5510424	0.99
# 3	Fast As a Shark	3	2	1	F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman	230619	3990994	0.99
# */以下はデータベース内のテーブルとそのサンプル行です：
#
# 1. **albums** テーブル:
#    - AlbumId: アルバムのID
#    - Title: アルバムのタイトル
#    - ArtistId: アーティストのID
#    - 例:
#      - AlbumId: 1, Title: For Those About To Rock We Salute You, ArtistId: 1
#      - AlbumId: 2, Title: Balls to the Wall, ArtistId: 2
#      - AlbumId: 3, Title: Restless and Wild, ArtistId: 2
#
# 2. **artists** テーブル:
#    - ArtistId: アーティストのID
#    - Name: アーティストの名前
#    - 例:
#      - ArtistId: 1, Name: AC/DC
#      - ArtistId: 2, Name: Accept
#      - ArtistId: 3, Name: Aerosmith
#
# 3. **customers** テーブル:
#    - CustomerId: 顧客のID
#    - FirstName: 顧客の名
#    - LastName: 顧客の姓
#    - 他の顧客情報
#    - SupportRepId: サポート担当者のID
#    - 例:
#      - CustomerId: 1, FirstName: Luís, LastName: Gonçalves, Email: luisg@embraer.com.br, SupportRepId: 3
#      - CustomerId: 2, FirstName: Leonie, LastName: Köhler, Email: leonekohler@surfeu.de, SupportRepId: 5
#      - CustomerId: 3, FirstName: François, LastName: Tremblay, Email: ftremblay@gmail.com, SupportRepId: 3
#
# 4. **employees** テーブル:
#    - EmployeeId: 従業員のID
#    - LastName: 従業員の姓
#    - FirstName: 従業員の名
#    - 他の従業員情報
#    - 例:
#      - EmployeeId: 1, LastName: Adams, FirstName: Andrew, Email: andrew@chinookcorp.com
#      - EmployeeId: 2, LastName: Edwards, FirstName: Nancy, Email: nancy@chinookcorp.com
#      - EmployeeId: 3, LastName: Peacock, FirstName: Jane, Email: jane@chinookcorp.com
#
# 5. **genres** テーブル:
#    - GenreId: ジャンルのID
#    - Name: ジャンルの名前
#    - 例:
#      - GenreId: 1, Name: Rock
#      - GenreId: 2, Name: Jazz
#      - GenreId: 3, Name: Metal
#
# 6. **invoice_items** テーブル:
#    - InvoiceLineId: 請求アイテムのID
#    - InvoiceId: 請求書のID
#    - TrackId: トラックのID
#    - UnitPrice: 単価
#    - Quantity: 数量
#    - 例:
#      - InvoiceLineId: 1, InvoiceId: 1, TrackId: 2, UnitPrice: 0.99, Quantity: 1
#      - InvoiceLineId: 2, InvoiceId: 1, TrackId: 4, UnitPrice: 0.99, Quantity: 1
#      - InvoiceLineId: 3, InvoiceId: 2, TrackId: 6, UnitPrice: 0.99, Quantity: 1
#
# 7. **invoices** テーブル:
#    - InvoiceId: 請求書のID
#    - CustomerId: 顧客のID
#    - InvoiceDate: 請求日
#    - 他の請求情報
#    - Total: 合計金額
#    - 例:
#      - InvoiceId: 1, CustomerId: 2, InvoiceDate: 2009-01-01, Total: 1.98
#      - InvoiceId: 2, CustomerId: 4, InvoiceDate: 2009-01-02, Total: 3.96
#      - InvoiceId: 3, CustomerId: 8, InvoiceDate: 2009-01-03, Total: 5.94
#
# 8. **media_types** テーブル:
#    - MediaTypeId: メディアタイプのID
#    - Name: メディアタイプの名前
#    - 例:
#      - MediaTypeId: 1, Name: MPEG audio file
#      - MediaTypeId: 2, Name: Protected AAC audio file
#      - MediaTypeId: 3, Name: Protected MPEG-4 video file
#
# 9. **playlist_track** テーブル:
#    - PlaylistId: プレイリストのID
#    - TrackId: トラックのID
#    - 例:
#      - PlaylistId: 1, TrackId: 3402
#      - PlaylistId: 1, TrackId: 3389
#      - PlaylistId: 1, TrackId: 3390
#
# 10. **playlists** テーブル:
#     - PlaylistId: プレイリストのID
#     - Name: プレイリストの名前
#     - 例:
#       - PlaylistId: 1, Name: Music
#       - PlaylistId: 2, Name: Movies
#       - PlaylistId: 3, Name: TV Shows
#
# 11. **tracks** テーブル:
#     - TrackId: トラックのID
#     - Name: トラックの名前
#     - AlbumId: アルバムのID
#     - MediaTypeId: メディアタイプのID
#     - GenreId: ジャンルのID
#     - Composer: 作曲者
#     - Milliseconds: 再生時間
#     - Bytes: バイト数
#     - UnitPrice: 単価
#     - 例:
#       - TrackId: 1, Name: For Those About To Rock (We Salute You), AlbumId: 1, MediaTypeId: 1, GenreId: 1, Composer: Angus Young, Malcolm Young, Brian Johnson, Milliseconds: 343719, Bytes: 11170334, UnitPrice: 0.99
#       - TrackId: 2, Name: Balls to the Wall, AlbumId: 2, MediaTypeId: 2, GenreId: 1, Composer: None, Milliseconds: 342562, Bytes: 5510424, UnitPrice: 0.99
#       - TrackId: 3, Name: Fast As a Shark, AlbumId: 3, MediaTypeId: 2, GenreId: 1, Composer: F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman, Milliseconds: 230619, Bytes: 3990994, UnitPrice: 0.99
#
# これらのテーブルとサンプル行から、データベース内の情報を取得できます。他に何かお手伝いできることがあればお知らせください。
#
# > Finished chain.
# '以下はデータベース内のテーブルとそのサンプル行です：\n\n1. **albums** テーブル:\n   - AlbumId: アルバムのID\n   - Title: アルバムのタイトル\n   - ArtistId: アーティストのID\n   - 例:\n     - AlbumId: 1, Title: For Those About To Rock We Salute You, ArtistId: 1\n     - AlbumId: 2, Title: Balls to the Wall, ArtistId: 2\n     - AlbumId: 3, Title: Restless and Wild, ArtistId: 2\n\n2. **artists** テーブル:\n   - ArtistId: アーティストのID\n   - Name: アーティストの名前\n   - 例:\n     - ArtistId: 1, Name: AC/DC\n     - ArtistId: 2, Name: Accept\n     - ArtistId: 3, Name: Aerosmith\n\n3. **customers** テーブル:\n   - CustomerId: 顧客のID\n   - FirstName: 顧客の名\n   - LastName: 顧客の姓\n   - 他の顧客情報\n   - SupportRepId: サポート担当者のID\n   - 例:\n     - CustomerId: 1, FirstName: Luís, LastName: Gonçalves, Email: luisg@embraer.com.br, SupportRepId: 3\n     - CustomerId: 2, FirstName: Leonie, LastName: Köhler, Email: leonekohler@surfeu.de, SupportRepId: 5\n     - CustomerId: 3, FirstName: François, LastName: Tremblay, Email: ftremblay@gmail.com, SupportRepId: 3\n\n4. **employees** テーブル:\n   - EmployeeId: 従業員のID\n   - LastName: 従業員の姓\n   - FirstName: 従業員の名\n   - 他の従業員情報\n   - 例:\n     - EmployeeId: 1, LastName: Adams, FirstName: Andrew, Email: andrew@chinookcorp.com\n     - EmployeeId: 2, LastName: Edwards, FirstName: Nancy, Email: nancy@chinookcorp.com\n     - EmployeeId: 3, LastName: Peacock, FirstName: Jane, Email: jane@chinookcorp.com\n\n5. **genres** テーブル:\n   - GenreId: ジャンルのID\n   - Name: ジャンルの名前\n   - 例:\n     - GenreId: 1, Name: Rock\n     - GenreId: 2, Name: Jazz\n     - GenreId: 3, Name: Metal\n\n6. **invoice_items** テーブル:\n   - InvoiceLineId: 請求アイテムのID\n   - InvoiceId: 請求書のID\n   - TrackId: トラックのID\n   - UnitPrice: 単価\n   - Quantity: 数量\n   - 例:\n     - InvoiceLineId: 1, InvoiceId: 1, TrackId: 2, UnitPrice: 0.99, Quantity: 1\n     - InvoiceLineId: 2, InvoiceId: 1, TrackId: 4, UnitPrice: 0.99, Quantity: 1\n     - InvoiceLineId: 3, InvoiceId: 2, TrackId: 6, UnitPrice: 0.99, Quantity: 1\n\n7. **invoices** テーブル:\n   - InvoiceId: 請求書のID\n   - CustomerId: 顧客のID\n   - InvoiceDate: 請求日\n   - 他の請求情報\n   - Total: 合計金額\n   - 例:\n     - InvoiceId: 1, CustomerId: 2, InvoiceDate: 2009-01-01, Total: 1.98\n     - InvoiceId: 2, CustomerId: 4, InvoiceDate: 2009-01-02, Total: 3.96\n     - InvoiceId: 3, CustomerId: 8, InvoiceDate: 2009-01-03, Total: 5.94\n\n8. **media_types** テーブル:\n   - MediaTypeId: メディアタイプのID\n   - Name: メディアタイプの名前\n   - 例:\n     - MediaTypeId: 1, Name: MPEG audio file\n     - MediaTypeId: 2, Name: Protected AAC audio file\n     - MediaTypeId: 3, Name: Protected MPEG-4 video file\n\n9. **playlist_track** テーブル:\n   - PlaylistId: プレイリストのID\n   - TrackId: トラックのID\n   - 例:\n     - PlaylistId: 1, TrackId: 3402\n     - PlaylistId: 1, TrackId: 3389\n     - PlaylistId: 1, TrackId: 3390\n\n10. **playlists** テーブル:\n    - PlaylistId: プレイリストのID\n    - Name: プレイリストの名前\n    - 例:\n      - PlaylistId: 1, Name: Music\n      - PlaylistId: 2, Name: Movies\n      - PlaylistId: 3, Name: TV Shows\n\n11. **tracks** テーブル:\n    - TrackId: トラックのID\n    - Name: トラックの名前\n    - AlbumId: アルバムのID\n    - MediaTypeId: メディアタイプのID\n    - GenreId: ジャンルのID\n    - Composer: 作曲者\n    - Milliseconds: 再生時間\n    - Bytes: バイト数\n    - UnitPrice: 単価\n    - 例:\n      - TrackId: 1, Name: For Those About To Rock (We Salute You), AlbumId: 1, MediaTypeId: 1, GenreId: 1, Composer: Angus Young, Malcolm Young, Brian Johnson, Milliseconds: 343719, Bytes: 11170334, UnitPrice: 0.99\n      - TrackId: 2, Name: Balls to the Wall, AlbumId: 2, MediaTypeId: 2, GenreId: 1, Composer: None, Milliseconds: 342562, Bytes: 5510424, UnitPrice: 0.99\n      - TrackId: 3, Name: Fast As a Shark, AlbumId: 3, MediaTypeId: 2, GenreId: 1, Composer: F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman, Milliseconds: 230619, Bytes: 3990994, UnitPrice: 0.99\n\nこれらのテーブルとサンプル行から、データベース内の情報を取得できます。他に何かお手伝いできることがあればお知らせください。'
